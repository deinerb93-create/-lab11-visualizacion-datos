# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('Bike_Sales_Outlier_Lab.xlsx')
data.columns = data.columns.str.strip()
print(data.columns.tolist())
# Out:
# ['Sales_Order #', 'Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category', 'Sub_Category', 'Product_Description', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']

# %%
ventas_por_dia = data.groupby('Date')['Order_Quantity'].sum().sort_values(ascending=False)
print(ventas_por_dia.head(10))
# Out:
# Date
# 2021-12-19    43
# 2021-12-18    19
# 2021-12-20    13
# 2021-12-12    12
# 2021-12-08    11
# 2021-12-05    10
# 2021-12-22    10
# 2021-12-10     8
# 2021-12-11     8
# 2021-12-07     6
# Name: Order_Quantity, dtype: int64

# %%
serie = data.groupby('Date')['Order_Quantity'].sum().sort_index()
plt.figure(figsize=(10,5))
plt.scatter(serie.index, serie.values, color='steelblue')
plt.title('Order_Quantity por fecha - Diciembre 2021')
plt.xlabel('Fecha')
plt.ylabel('Suma de Order_Quantity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top5 = serie.nlargest(5)
bottom6 = serie.nsmallest(6)
print('Top 5:', top5)
print('Bottom 6:', bottom6)
# Out:
# Top 5: Date
# 2021-12-19    43
# 2021-12-18    19
# 2021-12-20    13
# 2021-12-12    12
# 2021-12-08    11
# Name: Order_Quantity, dtype: int64
# Bottom 6: Date
# 2021-12-15    1
# 2021-12-02    3
# 2021-12-09    3
# 2021-12-23    3
# 2021-12-03    4
# 2021-12-04    4
# Name: Order_Quantity, dtype: int64

# %%
outlier_day = data[data['Date'] == '2021-12-19'].sort_values('Order_Quantity', ascending=False)
print(outlier_day[['Sales_Order #','Order_Quantity','Revenue']])
# Out:
#     Sales_Order #  Order_Quantity  Revenue
# 70         261765              11    25520
# 61         261756               4     9280
# 62         261757               4     2160
# 63         261758               4     9180
# 65         261760               4     9180
# 64         261759               4    13500
# 66         261761               4     9180
# 67         261762               4     9180
# 68         261763               2     1080
# 69         261764               2     4590

# %%
plt.figure(figsize=(10,6))
plt.scatter(data['Order_Quantity'], data['Revenue'], color='b', alpha=0.5)
plt.title('Relación entre la Cantidad de Órdenes y los Ingresos')
plt.xlabel('Cantidad de Órdenes')
plt.ylabel('Ingresos')
plt.show()

# %%
asignaturas = ['Matemáticas', 'Ciencias', 'Historia', 'Inglés', 'Arte']
calificaciones = [85, 90, 78, 88, 92]
plt.bar(asignaturas, calificaciones, color='teal')
plt.title('Promedio de Calificaciones por Asignatura')
plt.xlabel('Asignaturas'); plt.ylabel('Calificación Promedio')
plt.tight_layout(); plt.show()

# %%
sitios = ['Sitio A', 'Sitio B', 'Sitio C', 'Sitio D', 'Sitio E']
tiempos = [1.2, 2.5, 0.9, 3.0, 1.8]
plt.barh(sitios, tiempos, color='purple')
plt.title('Comparación de Tiempos de Carga de Sitios Web')
plt.xlabel('Tiempo de Carga (segundos)'); plt.ylabel('Sitios Web')
plt.tight_layout(); plt.show()

# %%
horas_estudio = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
calificaciones = [60, 65, 70, 75, 80, 85, 88, 90, 92, 95]
plt.scatter(horas_estudio, calificaciones, color='blue', s=100, edgecolor='black')
plt.title('Relación entre Horas de Estudio y Rendimiento Académico')
plt.xlabel('Horas de Estudio'); plt.ylabel('Calificación')
plt.tight_layout(); plt.show()

# %%
datos_salarios = {
 'Departamento': ['Recursos Humanos']*10 + ['IT']*10 + ['Administración']*10,
 'Salario': [3200,3400,3600,3800,4000,4200,4400,4600,4800,5000,
             5500,5700,6000,6200,6500,6700,7000,7200,7500,7800,
             4300,4500,4700,4900,5100,5300,5500,5700,5900,6100]
}
df_salarios = pd.DataFrame(datos_salarios)
sns.boxplot(x='Departamento', y='Salario', data=df_salarios, palette='Set1')
plt.title('Distribución de Salarios por Departamento')
plt.tight_layout(); plt.show()
# Out:
# /tmp/ipykernel_467/3357981722.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Departamento', y='Salario', data=df_salarios, palette='Set1')
